# %% [markdown]
# <a href="https://colab.research.google.com/github/meghanaaggadi-1/projects/blob/masterr/socailm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Importing details

# %%
import numpy
import math
import random
import pandas
import plotly.express as px

# %% [markdown]
# Data list input

# %%
product = pandas.read_csv('/content/drive/MyDrive/social_network.csv')
product.drop(['User ID'], axis = 1, inplace = True)
product.head(10)
# Out:
#   Social Media  Gender   Age  EstimatedSalary  Purchased
# 0     Facebook    Male  19.0          19000.0        0.0
# 1      Twitter    Male  35.0          20000.0        0.0
# 2    Instagram  Female  26.0          43000.0        0.0
# 3      Linkdin  Female  27.0          57000.0        0.0
# 4     Facebook    Male  19.0          76000.0        0.0
# 5      Twitter    Male  27.0          58000.0        0.0
# 6    Instagram  Female  27.0          84000.0        0.0
# 7      Linkdin  Female  32.0         150000.0        1.0
# 8     Facebook    Male  25.0          33000.0        0.0
# 9      Twitter  Female  35.0          65000.0        0.0

# %% [markdown]
# Binary conversions

# %%
varlist =  ['Gender']
def binary_map(x):
    return x.map({'Male': 1, "Female": 0})

product[varlist] = product[varlist].apply(binary_map)

# %% [markdown]
# Category conversions

# %%
status = pandas.get_dummies(product['Social Media'], drop_first = True)
product = pandas.concat([product, status], axis = 1)
product.drop(['Social Media'], axis = 1, inplace = True)
product
# Out:
#      Gender   Age  EstimatedSalary  Purchased  Instagram  Linkdin  Twitter
# 0       1.0  19.0          19000.0        0.0          0        0        0
# 1       1.0  35.0          20000.0        0.0          0        0        1
# 2       0.0  26.0          43000.0        0.0          1        0        0
# 3       0.0  27.0          57000.0        0.0          0        1        0
# 4       1.0  19.0          76000.0        0.0          0        0        0
# ..      ...   ...              ...        ...        ...      ...      ...
# 396     1.0  51.0          23000.0        1.0          0        0        1
# 397     0.0  50.0          20000.0        1.0          1        0        0
# 398     1.0  36.0          33000.0        0.0          0        1        0
# 399     0.0  49.0          36000.0        1.0          0        0        0
# 400     NaN   NaN              NaN        NaN          0        0        0
#
# [401 rows x 7 columns]

# %% [markdown]
# Finding For Null Values

# %%
print(product.isnull().sum())
# Out:
# Gender             1
# Age                1
# EstimatedSalary    1
# Purchased          1
# Instagram          0
# Linkdin            0
# Twitter            0
# dtype: int64

# %%
print(product.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    float64
#  1   Age              400 non-null    float64
#  2   EstimatedSalary  400 non-null    float64
#  3   Purchased        400 non-null    float64
#  4   Instagram        401 non-null    uint8
#  5   Linkdin          401 non-null    uint8
#  6   Twitter          401 non-null    uint8
# dtypes: float64(4), uint8(3)
# memory usage: 13.8 KB
# None

# %%
print(product.describe())
# Out:
#            Gender         Age  EstimatedSalary   Purchased   Instagram  \
# count  400.000000  400.000000       400.000000  400.000000  401.000000
# mean     0.490000   40.175000     69742.500000    0.357500    0.259352
# std      0.500526   31.709511     34096.960282    0.479864    0.438826
# min      0.000000   18.000000     15000.000000    0.000000    0.000000
# 25%      0.000000   30.000000     43000.000000    0.000000    0.000000
# 50%      0.000000   37.000000     70000.000000    0.000000    0.000000
# 75%      1.000000   46.000000     88000.000000    1.000000    1.000000
# max      1.000000  480.000000    150000.000000    1.000000    1.000000
#
#           Linkdin     Twitter
# count  401.000000  401.000000
# mean     0.216958    0.256858
# std      0.412688    0.437446
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    1.000000
# max      1.000000    1.000000

# %% [markdown]
# Outline detection

# %%
def detect_outliers_zscore(data):
    outliers = []
    thres = 1
    mean = numpy.mean(data)
    std = numpy.std(data)
    for i in data:
        z_score = (i-mean)/std
        if (numpy.abs(z_score) > thres):
            outliers.append(i)
    return outliers

# %%
sample_outliers_Age = detect_outliers_zscore(product['Age'])
print("Outliers in Age column from Z-scores method: ", sample_outliers_Age)
# Out:
# Outliers in Age column from Z-scores method:  [480.0, 270.0, 370.0]

# %%
print(product.describe())
# Out:
#            Gender         Age  EstimatedSalary   Purchased   Instagram  \
# count  400.000000  400.000000       400.000000  400.000000  401.000000
# mean     0.490000   40.175000     69742.500000    0.357500    0.259352
# std      0.500526   31.709511     34096.960282    0.479864    0.438826
# min      0.000000   18.000000     15000.000000    0.000000    0.000000
# 25%      0.000000   30.000000     43000.000000    0.000000    0.000000
# 50%      0.000000   37.000000     70000.000000    0.000000    0.000000
# 75%      1.000000   46.000000     88000.000000    1.000000    1.000000
# max      1.000000  480.000000    150000.000000    1.000000    1.000000
#
#           Linkdin     Twitter
# count  401.000000  401.000000
# mean     0.216958    0.256858
# std      0.412688    0.437446
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.000000    1.000000
# max      1.000000    1.000000

# %%
print(product.isnull().sum())
# Out:
# Gender             1
# Age                1
# EstimatedSalary    1
# Purchased          1
# Instagram          0
# Linkdin            0
# Twitter            0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
dataframe = product.values
X, y = dataframe[:, :-1], dataframe[:, -1]
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 10)
x_train
# Out:
# array([[0.00e+00, 4.60e+01, 9.60e+04, 0.00e+00, 1.00e+00, 0.00e+00],
#        [1.00e+00, 4.10e+01, 4.50e+04, 0.00e+00, 0.00e+00, 1.00e+00],
#        [1.00e+00, 2.70e+01, 8.80e+04, 0.00e+00, 1.00e+00, 0.00e+00],
#        ...,
#        [1.00e+00, 2.90e+01, 8.00e+04, 0.00e+00, 0.00e+00, 1.00e+00],
#        [0.00e+00, 3.90e+01, 6.10e+04, 0.00e+00, 0.00e+00, 0.00e+00],
#        [0.00e+00, 4.20e+01, 1.08e+05, 1.00e+00, 0.00e+00, 1.00e+00]])

# %%
fig = px.histogram(product, x = product['EstimatedSalary'], color = 'Purchased')
fig.show()
fig2 = px.box(product, x = product['EstimatedSalary'], color = 'Purchased')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7a8acd2-e994-4380-94ea-9c94911e5887" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7a8acd2-e994-4380-94ea-9c94911e5887")) {                    Plotly.newPlot(                        "b7a8acd2-e994-4380-94ea-9c94911e5887",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Purchased=0.0\u003cbr\u003eEstimatedSalary=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0.0","offsetgroup":"0.0","orientation":"v","showlegend":true,"x":[19000.0,20000.0,43000.0,57000.0,76000.0,58000.0,84000.0,33000.0,65000.0,80000.0,52000.0,86000.0,18000.0,82000.0,80000.0,43000.0,18000.0,74000.0,16000.0,44000.0,90000.0,27000.0,28000.0,49000.0,72000.0,31000.0,17000.0,51000.0,108000.0,15000.0,84000.0,20000.0,79000.0,54000.0,89000.0,32000.0,44000.0,83000.0,23000.0,58000.0,55000.0,48000.0,79000.0,18000.0,117000.0,20000.0,87000.0,66000.0,83000.0,58000.0,19000.0,82000.0,63000.0,68000.0,80000.0,27000.0,23000.0,113000.0,18000.0,52000.0,27000.0,87000.0,17000.0,80000.0,42000.0,49000.0,88000.0,62000.0,55000.0,85000.0,81000.0,50000.0,81000.0,116000.0,15000.0,28000.0,83000.0,44000.0,25000.0,73000.0,37000.0,88000.0,59000.0,86000.0,21000.0,72000.0,35000.0,89000.0,86000.0,80000.0,71000.0,71000.0,61000.0,55000.0,80000.0,57000.0,75000.0,52000.0,59000.0,59000.0,75000.0,72000.0,75000.0,53000.0,51000.0,61000.0,65000.0,32000.0,17000.0,84000.0,58000.0,31000.0,87000.0,68000.0,55000.0,63000.0,82000.0,59000.0,25000.0,85000.0,68000.0,59000.0,89000.0,25000.0,89000.0,30000.0,61000.0,74000.0,15000.0,45000.0,76000.0,50000.0,47000.0,15000.0,59000.0,75000.0,30000.0,90000.0,33000.0,38000.0,69000.0,86000.0,55000.0,71000.0,47000.0,88000.0,115000.0,118000.0,43000.0,72000.0,28000.0,47000.0,22000.0,23000.0,34000.0,16000.0,71000.0,43000.0,60000.0,66000.0,82000.0,41000.0,72000.0,32000.0,84000.0,26000.0,43000.0,70000.0,89000.0,43000.0,79000.0,36000.0,80000.0,22000.0,39000.0,74000.0,71000.0,47000.0,114000.0,22000.0,42000.0,58000.0,43000.0,65000.0,78000.0,96000.0,80000.0,60000.0,53000.0,72000.0,42000.0,112000.0,57000.0,80000.0,82000.0,59000.0,72000.0,50000.0,52000.0,39000.0,52000.0,44000.0,72000.0,57000.0,77000.0,72000.0,75000.0,74000.0,61000.0,133000.0,71000.0,61000.0,141000.0,62000.0,79000.0,77000.0,57000.0,63000.0,79000.0,60000.0,54000.0,134000.0,50000.0,70000.0,50000.0,79000.0,55000.0,60000.0,52000.0,60000.0,72000.0,75000.0,51000.0,65000.0,65000.0,54000.0,79000.0,55000.0,75000.0,65000.0,63000.0,77000.0,61000.0,75000.0,57000.0,72000.0,54000.0,79000.0,71000.0,73000.0,80000.0,74000.0,53000.0,64000.0,71000.0,59000.0,33000.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Purchased=1.0\u003cbr\u003eEstimatedSalary=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1.0","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1.0","offsetgroup":"1.0","orientation":"v","showlegend":true,"x":[150000.0,25000.0,26000.0,28000.0,29000.0,22000.0,49000.0,41000.0,22000.0,23000.0,20000.0,28000.0,30000.0,137000.0,135000.0,120000.0,112000.0,118000.0,123000.0,149000.0,107000.0,96000.0,135000.0,100000.0,148000.0,117000.0,134000.0,101000.0,130000.0,142000.0,96000.0,150000.0,108000.0,143000.0,91000.0,144000.0,102000.0,126000.0,133000.0,80000.0,147000.0,107000.0,86000.0,79000.0,143000.0,149000.0,88000.0,104000.0,146000.0,122000.0,97000.0,134000.0,146000.0,90000.0,95000.0,131000.0,144000.0,125000.0,90000.0,108000.0,144000.0,76000.0,42000.0,106000.0,26000.0,74000.0,88000.0,38000.0,36000.0,88000.0,70000.0,21000.0,93000.0,138000.0,78000.0,134000.0,89000.0,39000.0,73000.0,112000.0,117000.0,3 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="02a92efd-cdad-42fe-a90b-ee32556f06e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02a92efd-cdad-42fe-a90b-ee32556f06e7")) {                    Plotly.newPlot(                        "02a92efd-cdad-42fe-a90b-ee32556f06e7",                        [{"alignmentgroup":"True","hovertemplate":"Purchased=0.0\u003cbr\u003eEstimatedSalary=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0.0","marker":{"color":"#636efa"},"name":"0.0","notched":false,"offsetgroup":"0.0","orientation":"h","showlegend":true,"x":[19000.0,20000.0,43000.0,57000.0,76000.0,58000.0,84000.0,33000.0,65000.0,80000.0,52000.0,86000.0,18000.0,82000.0,80000.0,43000.0,18000.0,74000.0,16000.0,44000.0,90000.0,27000.0,28000.0,49000.0,72000.0,31000.0,17000.0,51000.0,108000.0,15000.0,84000.0,20000.0,79000.0,54000.0,89000.0,32000.0,44000.0,83000.0,23000.0,58000.0,55000.0,48000.0,79000.0,18000.0,117000.0,20000.0,87000.0,66000.0,83000.0,58000.0,19000.0,82000.0,63000.0,68000.0,80000.0,27000.0,23000.0,113000.0,18000.0,52000.0,27000.0,87000.0,17000.0,80000.0,42000.0,49000.0,88000.0,62000.0,55000.0,85000.0,81000.0,50000.0,81000.0,116000.0,15000.0,28000.0,83000.0,44000.0,25000.0,73000.0,37000.0,88000.0,59000.0,86000.0,21000.0,72000.0,35000.0,89000.0,86000.0,80000.0,71000.0,71000.0,61000.0,55000.0,80000.0,57000.0,75000.0,52000.0,59000.0,59000.0,75000.0,72000.0,75000.0,53000.0,51000.0,61000.0,65000.0,32000.0,17000.0,84000.0,58000.0,31000.0,87000.0,68000.0,55000.0,63000.0,82000.0,59000.0,25000.0,85000.0,68000.0,59000.0,89000.0,25000.0,89000.0,30000.0,61000.0,74000.0,15000.0,45000.0,76000.0,50000.0,47000.0,15000.0,59000.0,75000.0,30000.0,90000.0,33000.0,38000.0,69000.0,86000.0,55000.0,71000.0,47000.0,88000.0,115000.0,118000.0,43000.0,72000.0,28000.0,47000.0,22000.0,23000.0,34000.0,16000.0,71000.0,43000.0,60000.0,66000.0,82000.0,41000.0,72000.0,32000.0,84000.0,26000.0,43000.0,70000.0,89000.0,43000.0,79000.0,36000.0,80000.0,22000.0,39000.0,74000.0,71000.0,47000.0,114000.0,22000.0,42000.0,58000.0,43000.0,65000.0,78000.0,96000.0,80000.0,60000.0,53000.0,72000.0,42000.0,112000.0,57000.0,80000.0,82000.0,59000.0,72000.0,50000.0,52000.0,39000.0,52000.0,44000.0,72000.0,57000.0,77000.0,72000.0,75000.0,74000.0,61000.0,133000.0,71000.0,61000.0,141000.0,62000.0,79000.0,77000.0,57000.0,63000.0,79000.0,60000.0,54000.0,134000.0,50000.0,70000.0,50000.0,79000.0,55000.0,60000.0,52000.0,60000.0,72000.0,75000.0,51000.0,65000.0,65000.0,54000.0,79000.0,55000.0,75000.0,65000.0,63000.0,77000.0,61000.0,75000.0,57000.0,72000.0,54000.0,79000.0,71000.0,73000.0,80000.0,74000.0,53000.0,64000.0,71000.0,59000.0,33000.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"Purchased=1.0\u003cbr\u003eEstimatedSalary=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1.0","marker":{"color":"#EF553B"},"name":"1.0","notched":false,"offsetgroup":"1.0","orientation":"h","showlegend":true,"x":[150000.0,25000.0,26000.0,28000.0,29000.0,22000.0,49000.0,41000.0,22000.0,23000.0,20000.0,28000.0,30000.0,137000.0,135000.0,120000.0,112000.0,118000.0,123000.0,149000.0,107000.0,96000.0,135000.0,100000.0,148000.0,117000.0,134000.0,101000.0,130000.0,142000.0,96000.0,150000.0,108000.0,143000.0,91000.0,144000.0,102000.0,126000.0,133000.0,80000.0,147000.0,107000.0,86000.0,79000.0,143000.0,149000.0,88000.0,104000.0,146000.0,122000.0,97000.0,134000.0,146000.0,90000.0,95000.0,131000.0,144000.0,125000.0,90000.0,108000.0,144000.0,76000.0,42000.0,106000.0,26000.0,74000.0,88000.0,38000.0,36000.0,88000.0,70000.0,21000.0,93000.0,138000.0,78000.0,134000.0,89000.0,39000.0,73000.0,112000.0,117000.0,38000.0,74000.0,137000.0,79000.0,113000.0,125000.0,96000.0,141000.0,75000.0,10400 ...

# %% [markdown]
# Thank you ..
